# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhi-sys/StreamLit_12Days/blob/main/Hydration_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install streamlit
import pandas as pd
import numpy as np
import streamlit as st
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
st.markdown('<div class="main-title">💧 Hydration Predictor</div>', unsafe_allow_html=True)
st.header("Hydration Tracker")

data = pd.read_csv('Daily_Water_Intake.csv')
st.write("What is Your Age")
age=st.select_slider("Age", options=data['Age'].unique(), key='age_slider')
st.write("What is Your Gender")
gender=st.select_slider("Gender", options=data['Gender'].unique(), key='gender_slider')
st.write("What is Your Weight")
weight=st.select_slider("Weight", options=data['Weight (kg)'].unique(), key='weight_slider')
hydrate={
    'Good':1,
    'Poor':2,
    'Moderate':3
}


data['Hydration Level']=data['Hydration Level'].map(hydrate)
st.write("How much Hydrated do you Feel ?")
hydrated=st.select_slider("hydration-Level", options=data['Hydration Level'].unique(), key="Hydration Level")
# Out:
# 2026-01-26 14:47:33.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 14:47:33.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
data.head(5)
data.tail(5)
# Out:
#        Age  Gender  Weight (kg)  Daily Water Intake (liters)  \
# 29995   47    Male           97                         3.45
# 29996   49  Female          109                         5.32
# 29997   56  Female           54                         1.50
# 29998   36    Male          106                         4.00
# 29999   26  Female           98                         4.43
#
#       Physical Activity Level Weather  Hydration Level
# 29995                Moderate    Cold                1
# 29996                    High     Hot                1
# 29997                Moderate    Cold                2
# 29998                     Low     Hot                1
# 29999                Moderate     Hot                1

# %%
hydrate={
    'Good':1,
    'Poor':2,
    'Moderate':3
}


data['Hydration Level']=data['Hydration Level'].map(hydrate)
# Out:
# Unique values for 'Hydration Level' before mapping:
# ['Good' 'Poor']
# Value counts for 'Hydration Level' after mapping:
# Hydration Level
# 1    23915
# 2     6085
# Name: count, dtype: int64

# %%
data['Gender']=data['Gender'].map({'Male':0,'Female':1})
data['Gender'] = data['Gender'].fillna(2)
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split # Ensure this import is present
from sklearn.linear_model import LinearRegression # Import LinearRegression for regression task
features=["Age","Gender","Weight (kg)","Hydration Level"]
x=data[features]
y=data['Daily Water Intake (liters)']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
gender_mapping_for_prediction = {'Male':0, 'Female':1}

numerical_gender = gender_mapping_for_prediction.get(gender, 2)


input_data_df = pd.DataFrame([[age, numerical_gender, weight, hydrated]],
                             columns=features)

st.write("Your water intake must be around:")

st.markdown("---")
st.markdown('<div class="card">', unsafe_allow_html=True)
st.subheader(" Make Prediction")
if st.button("Predict"):
    predicted_litre_intake = model.predict(input_data_df)
    st.write(f"{predicted_litre_intake[0]:.2f} liters")
# Out:
# 2026-01-26 15:11:19.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-26 15:11:19.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
